# %%
import pandas as pd
df= pd.read_csv(r"C:\Users\BAPS\Desktop\Python\Datasets\airbnb_nyc_clean.csv")    #converts the csv file into dataframe

# %%
import pandas as pd
df2= pd.read_csv(r"C:\Users\BAPS\Desktop\Python\Datasets\airbnb_nyc_clean.csv",usecols=['name','id','neighbourhood_group'])   
#usecols() -> using this we can access particular columns for the whole csv
df2
# Out:
#              id                                               name  \
# 0       1001254                 Clean & quiet apt home by the park
# 1       1002102                              Skylit Midtown Castle
# 2       1002403                THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                              blank
# 4       1003689   Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                                ...
# 69300  57361342             Sunny budget friendly room in Bushwick
# 69301  57361894            Cozy Apartment on Bedford Ave, Brooklyn
# 69302  57362446                Your 1 bedroom home away from home!
# 69303  57362999  MASTER Cozy Bedroom Queen size 2 blocks Timesq...
# 69304  57363551        Sunny Brownstone Studio in BedStuy Brooklyn
#
#       neighbourhood_group
# 0                Brooklyn
# 1               Manhattan
# 2               Manhattan
# 3                Brooklyn
# ...

# %%
df
# Out:
#              id                                               name  \
# 0       1001254                 Clean & quiet apt home by the park
# 1       1002102                              Skylit Midtown Castle
# 2       1002403                THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                              blank
# 4       1003689   Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                                ...
# 69300  57361342             Sunny budget friendly room in Bushwick
# 69301  57361894            Cozy Apartment on Bedford Ave, Brooklyn
# 69302  57362446                Your 1 bedroom home away from home!
# 69303  57362999  MASTER Cozy Bedroom Queen size 2 blocks Timesq...
# 69304  57363551        Sunny Brownstone Studio in BedStuy Brooklyn
#
#            host_id host_identity_verified host_name neighbourhood_group  \
# 0      80014485718            unconfirmed  Madaline            Brooklyn
# ...

# %%
df['neighbourhood_group'].value_counts()
# Out:
# neighbourhood_group
# Manhattan        29587
# Brooklyn         27895
# Queens            9262
# Bronx             1912
# Staten Island      649
# Name: count, dtype: int64

# %%
len(df['neighbourhood'].unique())
# Out:
# 239

# %%
df['host_name'].value_counts()
# Out:
# host_name
# Michael            582
# David              499
# Alex               385
# Sonder (NYC)       374
# John               374
#                   ...
# Ashley Michelle      1
# Adam + Caro          1
# Ranjeet              1
# Yurika               1
# Ngoc                 1
# Name: count, Length: 13191, dtype: int64

# %%
sample_rows=df.sample(n=5,weights='review_rate_number',replace=False,random_state=777)
sample_rows
# Out:
#              id                                               name  \
# 11704   7465455    Luxurious studio apt. across from Battery Park!
# 23235  13834027  A Guest Room in a Bushwick Artist/Musician's Loft
# 4772    3636912                            Fabulous Family Getaway
# 33798  19667971   NEW! HUGE DESIGN LOFT w/ Rooftop in Williamsburg
# 58442  33278853   Metropolitan Brooklyn Oasis in Heart of Bed Stuy
#
#            host_id host_identity_verified host_name neighbourhood_group  \
# 11704  40044590112               verified      Kara           Manhattan
# 23235  98093423299               verified      Dave            Brooklyn
# 4772   22726490698            unconfirmed     Julia            Brooklyn
# 33798  29986348001               verified     Fleur            Brooklyn
# 58442   4639914510            unconfirmed    Derick            Brooklyn
#
#             neighbourhood       lat      long  instant_bookable  ...   price  \
# ...
