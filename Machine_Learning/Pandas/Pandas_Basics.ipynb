# %%
import pandas

mydataset = {
  'cars': ["BMW", "Volvo", "Ford","Audi","Mercedes"],
  'passings': [3, 7, 2, None,None ]
}
myvar1 = pandas.DataFrame(mydataset) #by this way we can also create a dataframe

print(myvar1)
# Out:
#        cars  passings
# 0       BMW       3.0
# 1     Volvo       7.0
# 2      Ford       2.0
# 3      Audi       NaN
# 4  Mercedes       NaN

# %%
import pandas as pd

# %%
calories = {"day1": 420, "day2": 380, "day3": 390}
myvar = pd.Series(calories)
myvar
#This creates a series from a dictionary
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64

# %%
a = [1, 7, 2,None]

myvar = pd.Series(a,index=['x','y','z','aa'])        #with custom labels we can give any index value to the unindexed series
# myvar = pd.Series(a)        #This is normal indecing 
print(myvar)
print(myvar['y'])
# Out:
# x     1.0
# y     7.0
# z     2.0
# aa    NaN
# dtype: float64
# 7.0

# %% [markdown]
# read_csv()-> allows use to read and load the csv

# %%
import pandas as pd
df= pd.read_csv(r"C:\Users\BAPS\Desktop\Python\Datasets\airbnb_nyc_clean.csv")

# %%
df['neighbourhood_group'].unique()
# Out:
# array(['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx'],
#       dtype=object)

# %%
df111=pd.read_csv(r"C:\Users\BAPS\Desktop\Python\Datasets\airbnb_nyc_clean.csv",usecols=["neighbourhood_group","neighbourhood","lat","long"])
df111
# Out:
#       neighbourhood_group       neighbourhood       lat      long
# 0                Brooklyn          Kensington  40.64749 -73.97237
# 1               Manhattan             Midtown  40.75362 -73.98377
# 2               Manhattan              Harlem  40.80902 -73.94190
# 3                Brooklyn        Clinton Hill  40.68514 -73.95976
# 4               Manhattan         East Harlem  40.79851 -73.94399
# ...                   ...                 ...       ...       ...
# 69300            Brooklyn            Bushwick  40.69370 -73.91006
# 69301            Brooklyn        Williamsburg  40.71284 -73.96284
# 69302           Manhattan     Upper West Side  40.79563 -73.97634
# 69303           Manhattan      Hell's Kitchen  40.76125 -73.98945
# 69304            Brooklyn  Bedford-Stuyvesant  40.68221 -73.94618
#
# [69305 rows x 4 columns]

# %%
df_= pd.read_csv(r"C:\Users\BAPS\Desktop\Python\Datasets\airbnb_nyc_clean.csv",na_values=["N/A"],sep='[:,|_]',engine='python')    #converts the csv file into dataframe
#na_values() -> this replace the N/A with NaN for the constant handling of missing values
#sep -> used to seprate values if different delimiters are present in file
#eng -> Use python engne for regex
df_
# Out:
#              id                                               name  \
# 0       1001254                 Clean & quiet apt home by the park
# 1       1002102                              Skylit Midtown Castle
# 2       1002403                THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                              blank
# 4       1003689                                         Entire Apt
# ...         ...                                                ...
# 69582  57361342             Sunny budget friendly room in Bushwick
# 69583  57361894                     "Cozy Apartment on Bedford Ave
# 69584  57362446                Your 1 bedroom home away from home!
# 69585  57362999  MASTER Cozy Bedroom Queen size 2 blocks Timesq...
# 69586  57363551        Sunny Brownstone Studio in BedStuy Brooklyn
#
#                                         host         id.1       host.1  \
# 0                                80014485718  unconfirmed     Madaline
# ...

# %%
import pandas as pd
df2= pd.read_csv(r"C:\Users\BAPS\Desktop\Python\Datasets\airbnb_nyc_clean.csv",usecols=['name','id','neighbourhood_group'])   
#usecols() -> using this we can access particular columns for the whole csv
df2
# Out:
#              id                                               name  \
# 0       1001254                 Clean & quiet apt home by the park
# 1       1002102                              Skylit Midtown Castle
# 2       1002403                THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                              blank
# 4       1003689   Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                                ...
# 69300  57361342             Sunny budget friendly room in Bushwick
# 69301  57361894            Cozy Apartment on Bedford Ave, Brooklyn
# 69302  57362446                Your 1 bedroom home away from home!
# 69303  57362999  MASTER Cozy Bedroom Queen size 2 blocks Timesq...
# 69304  57363551        Sunny Brownstone Studio in BedStuy Brooklyn
#
#       neighbourhood_group
# 0                Brooklyn
# 1               Manhattan
# 2               Manhattan
# 3                Brooklyn
# ...

# %%
df3=pd.read_csv(r"C:\Users\BAPS\Desktop\Python\Datasets\airbnb_nyc_clean.csv",index_col='id')       
#index_col() -> converts the column as index for the DF
df3
# Out:
#                                                        name      host_id  \
# id
# 1001254                  Clean & quiet apt home by the park  80014485718
# 1002102                               Skylit Midtown Castle  52335172823
# 1002403                 THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 1002755                                               blank  85098326012
# 1003689    Entire Apt: Spacious Studio/Loft by central park  92037596077
# ...                                                     ...          ...
# 57361342             Sunny budget friendly room in Bushwick  29964876857
# 57361894            Cozy Apartment on Bedford Ave, Brooklyn  92852058426
# 57362446                Your 1 bedroom home away from home!  95572379802
# 57362999  MASTER Cozy Bedroom Queen size 2 blocks Timesq...  80154173698
# 57363551        Sunny Brownstone Studio in BedStuy Brooklyn  11145329848
#
#          host_identity_verified host_name neighbourhood_group  \
# id
# ...

# %%
df4=pd.read_csv(r"C:\Users\BAPS\Desktop\Python\Datasets\airbnb_nyc_clean.csv",nrows=5)       
#nrows() -> Limits the number of rows to be read from the csv file
df4
# Out:
#         id                                              name      host_id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                             blank  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host_name neighbourhood_group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2            unconfirmed     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
#
#         lat      long  instant_bookable  ...  price service_fee  \
# ...

# %%
df5=pd.read_csv(r"C:\Users\BAPS\Desktop\Python\Datasets\airbnb_nyc_clean.csv",nrows=5,skiprows=[3]) 
#skiprows([n])-> the the number of rows/row passed inside
df5
#parse_dates=["Date of birth"] -> allows to convert date column into datetime object
# Out:
#         id                                              name      host_id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002755                                             blank  85098326012
# 3  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 4  1004098         Large Cozy 1 BR Apartment In Midtown East  45498551794
#
#   host_identity_verified host_name neighbourhood_group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2            unconfirmed     Garry            Brooklyn  Clinton Hill
# 3               verified    Lyndon           Manhattan   East Harlem
# 4               verified  Michelle           Manhattan   Murray Hill
#
#         lat      long  instant_bookable  ...  price service_fee  \
# ...

# %% [markdown]
# head()-> prints the first n rows

# %%
df.head()
# Out:
#         id                                              name      host_id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                             blank  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host_name neighbourhood_group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2            unconfirmed     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
#
#         lat      long  instant_bookable  ...  price service_fee  \
# ...

# %%
df[['id','neighbourhood']].head()       #prints the top rows for the particular column
# Out:
#         id neighbourhood
# 0  1001254    Kensington
# 1  1002102       Midtown
# 2  1002403        Harlem
# 3  1002755  Clinton Hill
# 4  1003689   East Harlem

# %%
df.select_dtypes(include="object")      #select columns of a specific dtypes
# Out:
#                                                     name  \
# 0                     Clean & quiet apt home by the park
# 1                                  Skylit Midtown Castle
# 2                    THE VILLAGE OF HARLEM....NEW YORK !
# 3                                                  blank
# 4       Entire Apt: Spacious Studio/Loft by central park
# ...                                                  ...
# 69300             Sunny budget friendly room in Bushwick
# 69301            Cozy Apartment on Bedford Ave, Brooklyn
# 69302                Your 1 bedroom home away from home!
# 69303  MASTER Cozy Bedroom Queen size 2 blocks Timesq...
# 69304        Sunny Brownstone Studio in BedStuy Brooklyn
#
#       host_identity_verified host_name neighbourhood_group  \
# 0                unconfirmed  Madaline            Brooklyn
# 1                   verified     Jenna           Manhattan
# 2                unconfirmed     Elise           Manhattan
# ...

# %%
s=df.sort_values(by='id',ascending=True)
s.head()        #using head after putting the data in ascending order by id
# Out:
#         id                                              name      host_id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                             blank  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host_name neighbourhood_group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2            unconfirmed     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
#
#         lat      long  instant_bookable  ...  price service_fee  \
# ...

# %% [markdown]
# tail()-> prints last n rows of df

# %%
df.tail()
# Out:
#              id                                               name  \
# 69300  57361342             Sunny budget friendly room in Bushwick
# 69301  57361894            Cozy Apartment on Bedford Ave, Brooklyn
# 69302  57362446                Your 1 bedroom home away from home!
# 69303  57362999  MASTER Cozy Bedroom Queen size 2 blocks Timesq...
# 69304  57363551        Sunny Brownstone Studio in BedStuy Brooklyn
#
#            host_id host_identity_verified host_name neighbourhood_group  \
# 69300  29964876857               verified     blank            Brooklyn
# 69301  92852058426            unconfirmed     blank            Brooklyn
# 69302  95572379802               verified     blank           Manhattan
# 69303  80154173698               verified     blank           Manhattan
# 69304  11145329848            unconfirmed     Jamal            Brooklyn
#
#             neighbourhood       lat      long  instant_bookable  ...  \
# ...

# %%
df[['id','neighbourhood']].tail()
# Out:
#              id       neighbourhood
# 69300  57361342            Bushwick
# 69301  57361894        Williamsburg
# 69302  57362446     Upper West Side
# 69303  57362999      Hell's Kitchen
# 69304  57363551  Bedford-Stuyvesant

# %%
s=df.sort_values(by='id',ascending=True)
s.tail()
# Out:
#              id                                               name  \
# 69300  57361342             Sunny budget friendly room in Bushwick
# 69301  57361894            Cozy Apartment on Bedford Ave, Brooklyn
# 69302  57362446                Your 1 bedroom home away from home!
# 69303  57362999  MASTER Cozy Bedroom Queen size 2 blocks Timesq...
# 69304  57363551        Sunny Brownstone Studio in BedStuy Brooklyn
#
#            host_id host_identity_verified host_name neighbourhood_group  \
# 69300  29964876857               verified     blank            Brooklyn
# 69301  92852058426            unconfirmed     blank            Brooklyn
# 69302  95572379802               verified     blank           Manhattan
# 69303  80154173698               verified     blank           Manhattan
# 69304  11145329848            unconfirmed     Jamal            Brooklyn
#
#             neighbourhood       lat      long  instant_bookable  ...  \
# ...

# %%
df.shape        #gives the shape[rows*column] of the dataframe
# Out:
# (69305, 23)

# %%
df.info()   #gives the information about the dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69305 entries, 0 to 69304
# Data columns (total 23 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              69305 non-null  int64
#  1   name                            69305 non-null  object
#  2   host_id                         69305 non-null  int64
#  3   host_identity_verified          69305 non-null  object
#  4   host_name                       69305 non-null  object
#  5   neighbourhood_group             69305 non-null  object
#  6   neighbourhood                   69305 non-null  object
#  7   lat                             69305 non-null  float64
#  8   long                            69305 non-null  float64
#  9   instant_bookable                69305 non-null  bool
#  10  cancellation_policy             69305 non-null  object
#  11  room_type                       69305 non-null  object
# ...

# %%
df.head()       #prints the top records , by default value=5
# Out:
#         id                                              name      host_id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                             blank  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host_name neighbourhood_group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2            unconfirmed     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
#
#         lat      long  instant_bookable  ...  price service_fee  \
# ...

# %%
df.tail()       #prints the bottom rows,by default value is 5
# Out:
#              id                                               name  \
# 69300  57361342             Sunny budget friendly room in Bushwick
# 69301  57361894            Cozy Apartment on Bedford Ave, Brooklyn
# 69302  57362446                Your 1 bedroom home away from home!
# 69303  57362999  MASTER Cozy Bedroom Queen size 2 blocks Timesq...
# 69304  57363551        Sunny Brownstone Studio in BedStuy Brooklyn
#
#            host_id host_identity_verified host_name neighbourhood_group  \
# 69300  29964876857               verified     blank            Brooklyn
# 69301  92852058426            unconfirmed     blank            Brooklyn
# 69302  95572379802               verified     blank           Manhattan
# 69303  80154173698               verified     blank           Manhattan
# 69304  11145329848            unconfirmed     Jamal            Brooklyn
#
#             neighbourhood       lat      long  instant_bookable  ...  \
# ...

# %%
df.describe()       #prints various information about the df
# Out:
#                  id       host_id           lat          long  \
# count  6.930500e+04  6.930500e+04  69305.000000  69305.000000
# mean   2.015746e+07  4.929192e+10     40.728070    -73.949036
# std    1.109105e+07  2.854010e+10      0.055973      0.050470
# min    1.001254e+06  1.303496e+08     40.499790    -74.249840
# 25%    1.057049e+07  2.459948e+10     40.688540    -73.982790
# 50%    2.013964e+07  4.915407e+10     40.722650    -73.954390
# 75%    2.970878e+07  7.406137e+10     40.762730    -73.931380
# max    5.736355e+07  9.876313e+10     40.916970    -73.705220
#
#        construction_year         price   service_fee  minimum_nights  \
# count       69305.000000  69305.000000  69305.000000    69305.000000
# mean         2012.489503    624.736070    124.894026        4.620330
# std             5.756144    331.158937     66.222794        4.356887
# min          2003.000000     50.000000     10.000000        0.000000
# ...

# %%
df.iloc[:3] #slices the df into desired size and upper limit is excluded
# Out:
#         id                                 name      host_id  \
# 0  1001254   Clean & quiet apt home by the park  80014485718
# 1  1002102                Skylit Midtown Castle  52335172823
# 2  1002403  THE VILLAGE OF HARLEM....NEW YORK !  78829239556
#
#   host_identity_verified host_name neighbourhood_group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2            unconfirmed     Elise           Manhattan        Harlem
#
#         lat      long  instant_bookable  ...  price service_fee  \
# 0  40.64749 -73.97237             False  ...  966.0       193.0
# 1  40.75362 -73.98377             False  ...  142.0        28.0
# 2  40.80902 -73.94190              True  ...  620.0       124.0
#
#    minimum_nights  number_of_reviews  last_review  reviews_per_month  \
# 0            10.0                9.0   2021-10-19               0.21
# ...

# %%
df.loc[:3]  # #slices the df into desired size and upper limit is included
# Out:
#         id                                 name      host_id  \
# 0  1001254   Clean & quiet apt home by the park  80014485718
# 1  1002102                Skylit Midtown Castle  52335172823
# 2  1002403  THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                blank  85098326012
#
#   host_identity_verified host_name neighbourhood_group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2            unconfirmed     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
#
#         lat      long  instant_bookable  ...  price service_fee  \
# 0  40.64749 -73.97237             False  ...  966.0       193.0
# 1  40.75362 -73.98377             False  ...  142.0        28.0
# 2  40.80902 -73.94190              True  ...  620.0       124.0
# ...

# %%
a=pd.Series(df['name'])       #prints the dataof a column of a df in a series
print(a)                      #Series is 1D array holding any type of data
# Out:
# 0                       Clean & quiet apt home by the park
# 1                                    Skylit Midtown Castle
# 2                      THE VILLAGE OF HARLEM....NEW YORK !
# 3                                                    blank
# 4         Entire Apt: Spacious Studio/Loft by central park
#                                ...
# 69300               Sunny budget friendly room in Bushwick
# 69301              Cozy Apartment on Bedford Ave, Brooklyn
# 69302                  Your 1 bedroom home away from home!
# 69303    MASTER Cozy Bedroom Queen size 2 blocks Timesq...
# 69304          Sunny Brownstone Studio in BedStuy Brooklyn
# Name: name, Length: 69305, dtype: object

# %%
c=pd.Series(df["name"],index=[2,3,4,4,5])        #This allows us get any particular index value from the series
print(c)
# Out:
# 2                 THE VILLAGE OF HARLEM....NEW YORK !
# 3                                               blank
# 4    Entire Apt: Spacious Studio/Loft by central park
# 4    Entire Apt: Spacious Studio/Loft by central park
# 5           Large Cozy 1 BR Apartment In Midtown East
# Name: name, dtype: object

# %%
df.id       #Access a column in DF
# Out:
# 0         1001254
# 1         1002102
# 2         1002403
# 3         1002755
# 4         1003689
#            ...
# 69300    57361342
# 69301    57361894
# 69302    57362446
# 69303    57362999
# 69304    57363551
# Name: id, Length: 69305, dtype: int64

# %%
df[['id','name']]       #Access multiple columns of of df
# Out:
#              id                                               name
# 0       1001254                 Clean & quiet apt home by the park
# 1       1002102                              Skylit Midtown Castle
# 2       1002403                THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                              blank
# 4       1003689   Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                                ...
# 69300  57361342             Sunny budget friendly room in Bushwick
# 69301  57361894            Cozy Apartment on Bedford Ave, Brooklyn
# 69302  57362446                Your 1 bedroom home away from home!
# 69303  57362999  MASTER Cozy Bedroom Queen size 2 blocks Timesq...
# 69304  57363551        Sunny Brownstone Studio in BedStuy Brooklyn
#
# [69305 rows x 2 columns]

# %%
df1 = pd.DataFrame({'num_legs': [2, 4, 8, 0],                    
                   'num_wings': [2, 0, 0, 0],
                   'num_specimen_seen': [10, 2, 1, 8]},
                 index=['falcon', 'dog', 'spider', 'fish']) #this creates the index with the custom names

df1
# Out:
#         num_legs  num_wings  num_specimen_seen
# falcon         2          2                 10
# dog            4          0                  2
# spider         8          0                  1
# fish           0          0                  8

# %% [markdown]
# Sample() -> prints few lines of df as an sample in random order

# %%
sample_rows=df1.sample(2)        # prints that number of lines of DF that is given inside the sample(n)
sample_rows
# Out:
#         num_legs  num_wings  num_specimen_seen
# spider         8          0                  1
# fish           0          0                  8

# %%
sample_rows=df1.sample(frac=0.5)        # prints that percentage of DF that is given in the "frac="  
# 0.5 means 50% of the total DF
sample_rows
# Out:
#         num_legs  num_wings  num_specimen_seen
# dog            4          0                  2
# falcon         2          2                 10

# %%
df1['num_legs'].sample(n=3,random_state=1)      # is used to reproduce the randomness of the sample
# Out:
# fish      0
# spider    8
# falcon    2
# Name: num_legs, dtype: int64

# %%
df1.sample(n=3,replace=True)    # replace is sampling with replacemnet meaning,when "replace=True" each row can appear multiple time,but when "replace=False" each row will appear uniquely.
# Out:
#         num_legs  num_wings  num_specimen_seen
# falcon         2          2                 10
# spider         8          0                  1
# spider         8          0                  1

# %%
df1.sample(n=2,weights="num_specimen_seen",random_state=1)     # weights is to put empahsis on the given column,column with larger particular value will have greater chances of getting sampled
# Out:
#         num_legs  num_wings  num_specimen_seen
# falcon         2          2                 10
# fish           0          0                  8

# %% [markdown]
# .info() -> Provides the details of the DF

# %%
df1.info()
#Non-Null Count-> tells if there are any null values in the particular column
#Dtype -> DataType of the column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, falcon to fish
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   num_legs           4 non-null      int64
#  1   num_wings          4 non-null      int64
#  2   num_specimen_seen  4 non-null      int64
# dtypes: int64(3)
# memory usage: 128.0+ bytes

# %%
df1.info(verbose=True)      #prints the complete detail of the df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, falcon to fish
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   num_legs           4 non-null      int64
#  1   num_wings          4 non-null      int64
#  2   num_specimen_seen  4 non-null      int64
# dtypes: int64(3)
# memory usage: 128.0+ bytes

# %%
df1.info(verbose=False)     #prints a consice information of the df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, falcon to fish
# Columns: 3 entries, num_legs to num_specimen_seen
# dtypes: int64(3)
# memory usage: 128.0+ bytes

# %%
df1.info(memory_usage=True)      #prints basic memory usage
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, falcon to fish
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   num_legs           4 non-null      int64
#  1   num_wings          4 non-null      int64
#  2   num_specimen_seen  4 non-null      int64
# dtypes: int64(3)
# memory usage: 128.0+ bytes

# %%
df1.info(memory_usage='deep')       #prints the deep analysis of memory usage
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, falcon to fish
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   num_legs           4 non-null      int64
#  1   num_wings          4 non-null      int64
#  2   num_specimen_seen  4 non-null      int64
# dtypes: int64(3)
# memory usage: 343.0 bytes

# %% [markdown]
# #if i call "memory_usage=" explicitly deep and True will work the same the basic memory usage is by default printed with info()

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, falcon to fish
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   num_legs           4 non-null      int64
#  1   num_wings          4 non-null      int64
#  2   num_specimen_seen  4 non-null      int64
# dtypes: int64(3)
# memory usage: 128.0+ bytes

# %% [markdown]
# dtypes()-> returns the datatypes of each column

# %%
df.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_identity_verified             object
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# lat                               float64
# long                              float64
# instant_bookable                     bool
# cancellation_policy                object
# room_type                          object
# construction_year                 float64
# price                             float64
# service_fee                       float64
# minimum_nights                    float64
# number_of_reviews                 float64
# last_review                        object
# reviews_per_month                 float64
# review_rate_number                float64
# calculated_host_listings_count    float64
# availability_365                  float64
# ...

# %% [markdown]
# Size() -> return the size of dataframe [rows*columns]

# %%
df.size
# Out:
# 1594015

# %% [markdown]
# shape() -> return the shape of df

# %%
df.shape
# Out:
# (69305, 23)

# %% [markdown]
# ndim() -> return the dimension of the data

# %%
df.ndim         # 2==DataFrame[2d]
# Out:
# 2

# %%
df['id'].ndim       #1==Series[1D]
# Out:
# 1

# %% [markdown]
# Describe() -> returns the statistical summary of the columns of the df

# %%
df.describe()       #returns the statistical summary of the numeric columns of the df
# Out:
#                  id       host_id           lat          long  \
# count  6.930500e+04  6.930500e+04  69305.000000  69305.000000
# mean   2.015746e+07  4.929192e+10     40.728070    -73.949036
# std    1.109105e+07  2.854010e+10      0.055973      0.050470
# min    1.001254e+06  1.303496e+08     40.499790    -74.249840
# 25%    1.057049e+07  2.459948e+10     40.688540    -73.982790
# 50%    2.013964e+07  4.915407e+10     40.722650    -73.954390
# 75%    2.970878e+07  7.406137e+10     40.762730    -73.931380
# max    5.736355e+07  9.876313e+10     40.916970    -73.705220
#
#        construction_year         price   service_fee  minimum_nights  \
# count       69305.000000  69305.000000  69305.000000    69305.000000
# mean         2012.489503    624.736070    124.894026        4.620330
# std             5.756144    331.158937     66.222794        4.356887
# min          2003.000000     50.000000     10.000000        0.000000
# ...

# %%
percentiles = [.20, .40, .60, .80]
include = ['object', 'float', 'int']
#Through this we can give custom percentiles into the describe
desc = df.describe(percentiles=percentiles, include=include)
print(desc)
# Out:
#                   id   name       host_id host_identity_verified host_name  \
# count   6.930500e+04  69305  6.930500e+04                  69305     69305
# unique           NaN  61234           NaN                      2     13191
# top              NaN  blank           NaN            unconfirmed   Michael
# freq             NaN    208           NaN                  34779       582
# mean    2.015746e+07    NaN  4.929192e+10                    NaN       NaN
# std     1.109105e+07    NaN  2.854010e+10                    NaN       NaN
# min     1.001254e+06    NaN  1.303496e+08                    NaN       NaN
# 20%     8.656656e+06    NaN  1.967006e+10                    NaN       NaN
# 40%     1.631198e+07    NaN  3.934433e+10                    NaN       NaN
# 50%     2.013964e+07    NaN  4.915407e+10                    NaN       NaN
# 60%     2.396730e+07    NaN  5.906304e+10                    NaN       NaN
# ...

# %%
df['name'].describe()       #when used with string data it gives different parameters
# Out:
# count     69305
# unique    61234
# top       blank
# freq        208
# Name: name, dtype: object

# %%
df['id'].describe()             #provides the data for a particular column
# Out:
# count    6.930500e+04
# mean     2.015746e+07
# std      1.109105e+07
# min      1.001254e+06
# 25%      1.057049e+07
# 50%      2.013964e+07
# 75%      2.970878e+07
# max      5.736355e+07
# Name: id, dtype: float64

# %%
df.describe(include='all')      #includes all the column regardless of the datatype
# Out:
#                   id   name       host_id host_identity_verified host_name  \
# count   6.930500e+04  69305  6.930500e+04                  69305     69305
# unique           NaN  61234           NaN                      2     13191
# top              NaN  blank           NaN            unconfirmed   Michael
# freq             NaN    208           NaN                  34779       582
# mean    2.015746e+07    NaN  4.929192e+10                    NaN       NaN
# std     1.109105e+07    NaN  2.854010e+10                    NaN       NaN
# min     1.001254e+06    NaN  1.303496e+08                    NaN       NaN
# 25%     1.057049e+07    NaN  2.459948e+10                    NaN       NaN
# 50%     2.013964e+07    NaN  4.915407e+10                    NaN       NaN
# 75%     2.970878e+07    NaN  7.406137e+10                    NaN       NaN
# max     5.736355e+07    NaN  9.876313e+10                    NaN       NaN
#
# ...

# %% [markdown]
# unique() -> returns the unique values in particular column ,will not work on Df

# %%
df["neighbourhood_group"].unique()
# Out:
# array(['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx'],
#       dtype=object)

# %% [markdown]
# nunique() -> returns the number of unique valus in the column

# %%
df["neighbourhood_group"].nunique()
# Out:
# 5

# %% [markdown]
# isnull() -> returns a bool value if series object contains a null value

# %%
myvar.isnull()
# Out:
# x     False
# y     False
# z     False
# aa     True
# dtype: bool

# %%
df['name'].isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 69300    False
# 69301    False
# 69302    False
# 69303    False
# 69304    False
# Name: name, Length: 69305, dtype: bool

# %% [markdown]
# isna() -> returns bool for none value in df or in series

# %%
myvar.isna()
# Out:
# x     False
# y     False
# z     False
# aa     True
# dtype: bool

# %%
df.isna()
# Out:
#           id   name  host_id  host_identity_verified  host_name  \
# 0      False  False    False                   False      False
# 1      False  False    False                   False      False
# 2      False  False    False                   False      False
# 3      False  False    False                   False      False
# 4      False  False    False                   False      False
# ...      ...    ...      ...                     ...        ...
# 69300  False  False    False                   False      False
# 69301  False  False    False                   False      False
# 69302  False  False    False                   False      False
# 69303  False  False    False                   False      False
# 69304  False  False    False                   False      False
#
#        neighbourhood_group  neighbourhood    lat   long  instant_bookable  \
# 0                    False          False  False  False             False
# ...

# %% [markdown]
# fillna() -> used to fill a value inplace of none in df
#
#
#
# -> in current pandas version it will not work on a particular column or series

# %%
import pandas

mydataset = {
  'cars': ["BMW", "Volvo", "Ford","Audi","Mercedes"],
  'passings': [3, 7, 2, None,None ]
}
myvar1 = pandas.DataFrame(mydataset) #by this way we can also create a dataframe

print(myvar1)
# Out:
#        cars  passings
# 0       BMW       3.0
# 1     Volvo       7.0
# 2      Ford       2.0
# 3      Audi       NaN
# 4  Mercedes       NaN

# %%
myvar1
# Out:
#        cars  passings
# 0       BMW       3.0
# 1     Volvo       7.0
# 2      Ford       2.0
# 3      Audi       NaN
# 4  Mercedes       NaN

# %%
myvar1['cars'].fillna("No passing",inplace=True)        #puts the a particular value in place of none
myvar1

# %%
total_missing = myvar1.isnull().sum()
percentage_missing = total_missing * 100 / len(myvar1)
missing_value_df = pd.DataFrame(data=[total_missing, percentage_missing], index=["Total", "%"]).T
missing_value_df        #Using this wat we can calculate the count and
# Out:
#           Total     %
# cars        0.0   0.0
# passings    2.0  40.0

# %%
myvar1['passings'] = myvar1['passings'].fillna(myvar1['passings'].mean())       #this is how you handle missing values in an dataframe

# %%
myvar1
# Out:
#        cars  passings
# 0       BMW       3.0
# 1     Volvo       7.0
# 2      Ford       2.0
# 3      Audi       4.0
# 4  Mercedes       4.0

# %%
# myvar1.ffill(inplace=False)      #puts the value of upper row into the none untill next valued is found
myvar1                           #inplace() -> flag to replace the value in place of the nan
# Out:
#        cars  passings
# 0       BMW       3.0
# 1     Volvo       7.0
# 2      Ford       2.0
# 3      Audi       4.0
# 4  Mercedes       4.0

# %%
myvar1.ffill(inplace=True,limit=1)      #limit=() -> limits the ffill to filll upto only a particular value
myvar1
# Out:
#        cars  passings
# 0       BMW       3.0
# 1     Volvo       7.0
# 2      Ford       2.0
# 3      Audi       4.0
# 4  Mercedes       4.0

# %%
myvar2=myvar1

# %% [markdown]
# clip() -> puts values in a particular range

# %%
myvar.clip(1,11)
# Out:
# x     1.0
# y     7.0
# z     2.0
# aa    NaN
# dtype: float64

# %% [markdown]
# .columns() -> returns a list of columns in the df

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_identity_verified', 'host_name',
#        'neighbourhood_group', 'neighbourhood', 'lat', 'long',
#        'instant_bookable', 'cancellation_policy', 'room_type',
#        'construction_year', 'price', 'service_fee', 'minimum_nights',
#        'number_of_reviews', 'last_review', 'reviews_per_month',
#        'review_rate_number', 'calculated_host_listings_count',
#        'availability_365', 'house_rules'],
#       dtype='object')

# %% [markdown]
# index() -> returns index in df or in series

# %%
myvar.index
# Out:
# Index(['x', 'y', 'z', 'aa'], dtype='object')

# %% [markdown]
# sort_values() -> sorts value in df on the basis of one or more columns in asc or desc

# %%
myvar1
# Out:
#        cars  passings
# 0       BMW       3.0
# 1     Volvo       7.0
# 2      Ford       2.0
# 3      Audi       4.0
# 4  Mercedes       4.0

# %%
# myvar1.sort_values("passings",ascending=True,inplace=True,na_position='first')
# # arg1 -> col of df
# # arg2 -> 'ascending=' tells whether to sort in asc or desc,default is asc
# # arg3 -> 'inplace' is a flag when true modifies the original data
# # arg4 -> 'na_position' tells where to put the none values [first or last] , by default last
# myvar1

# %% [markdown]
# value_counts() -> counts the occurane of unique elements in the series

# %%
df['host_id'].value_counts(normalize=True,sort=True,ascending=True,bins=6,dropna=False)
#   normalize -> shows the percentage of the values of how many times they come 
#   sort -> Sorts by the frequency by showing higher frequency first
#   ascending -> sorts data in asc or desc
#   bins -> divids the data into parts of equal size
#   dropna -> flag when true doesn't show NaN values, else also shows them
# Out:
# (49446739318.0, 65885535886.667]      0.164389
# (82324332455.333, 98763129024.0]      0.166279
# (65885535886.667, 82324332455.333]    0.166380
# (33007942749.333, 49446739318.0]      0.166640
# (16569146180.667, 33007942749.333]    0.167795
# (31716832.587, 16569146180.667]       0.168516
# Name: proportion, dtype: float64

# %%
myvar1.value_counts()
# Out:
# cars      passings
# Audi      4.0         1
# BMW       3.0         1
# Ford      2.0         1
# Mercedes  4.0         1
# Volvo     7.0         1
# Name: count, dtype: int64

# %% [markdown]
# nlargest() -> returns the n largest rows based on a particular column n df
#
#
# another way to this is to use sort_values

# %%
df.nlargest(1,"review_rate_number")     
# agr1-> number of rows
# arg2 -> column name
# arg3(optional) -> 'keep' tells whether to keep the duplicate values i.e. first or last
# Out:
#         id                                 name      host_id  \
# 2  1002403  THE VILLAGE OF HARLEM....NEW YORK !  78829239556
#
#   host_identity_verified host_name neighbourhood_group neighbourhood  \
# 2            unconfirmed     Elise           Manhattan        Harlem
#
#         lat     long  instant_bookable  ...  price service_fee  \
# 2  40.80902 -73.9419              True  ...  620.0       124.0
#
#    minimum_nights  number_of_reviews  last_review  reviews_per_month  \
# 2             3.0                0.0   2019-06-14               0.79
#
#    review_rate_number calculated_host_listings_count  availability_365  \
# 2                 5.0                            1.0             352.0
#
#                                          house_rules
# 2  I encourage you to use my kitchen, cooking and...
#
# [1 rows x 23 columns]

# %% [markdown]
# nsmallest() -> returns n smallest rows based on the particular column

# %%
df.nsmallest(4,'minimum_nights')
# agr1-> number of rows
# arg2 -> column name
# arg3(optional) -> 'keep' tells whether to keep the duplicate values i.e. first or last
# Out:
#           id                                            name      host_id  \
# 176  1098541             BROOKLYN VICTORIAN STYLE SUITE.....  83631499592
# 352  1195746  Beautiful, Bright’s, Warm & Spacious 1.5BR Apt   2227683633
# 398  1221151              SUPER BIG AND COZY PRIVATE BEDROOM  50336791874
# 421  1233854                     Charming Nolita Apartment!!   7389895192
#
#     host_identity_verified  host_name neighbourhood_group  neighbourhood  \
# 176            unconfirmed  Frederick            Brooklyn    Fort Greene
# 352            unconfirmed      Grant            Brooklyn  Crown Heights
# 398               verified     Tucker            Brooklyn     Kensington
# 421               verified    Belinda           Manhattan         Nolita
#
#           lat      long  instant_bookable  ...   price service_fee  \
# 176  40.69098 -73.97113             False  ...  1155.0       231.0
# 352  40.67174 -73.95663              True  ...    73.0        15.0
# ...

# %% [markdown]
# copy() -> create a copy of df into another variabele

# %%
df_cpoy=df.copy()
#arg1(optional) -> deep=True creates a deep copy, if deep=False it creates a shallow copy

# %% [markdown]
# loc() -> can access a group  of rows and columns

# %%
df.loc[0:4]     #upper_limit is included
# Out:
#         id                                              name      host_id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                             blank  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host_name neighbourhood_group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2            unconfirmed     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
#
#         lat      long  instant_bookable  ...  price service_fee  \
# ...

# %%
df.loc[323,'host_name'] # can access a particular column from the df
# Out:
# 'Ellis'

# %%
df['neighbourhood_group'].loc[333:340]    #access value of a particular column and multiple rows
# Out:
# 333     Brooklyn
# 334    Manhattan
# 335     Brooklyn
# 336     Brooklyn
# 337     Brooklyn
# 338     Brooklyn
# 339    Manhattan
# 340     Brooklyn
# Name: neighbourhood_group, dtype: object

# %%
df.loc[333:340,["host_name","neighbourhood_group"] ]    #can access values of multiple columns and multiple rows
# Out:
#     host_name neighbourhood_group
# 333      Cole            Brooklyn
# 334    Carter           Manhattan
# 335     Ellis            Brooklyn
# 336   Hawkins            Brooklyn
# 337     Mason            Brooklyn
# 338  Anderson            Brooklyn
# 339  Crawford           Manhattan
# 340     Allen            Brooklyn

# %%
df.loc[df['review_rate_number']>4.5]        #to get a few rows based on few conditions
# Out:
#              id                                               name  \
# 2       1002403                THE VILLAGE OF HARLEM....NEW YORK !
# 6       1004650                                    BlissArtsSpace!
# 7       1005202                                    BlissArtsSpace!
# 9       1006307                 Cozy Clean Guest Room - Family Apt
# 17      1010725                  Perfect for Your Parents + Garden
# ...         ...                                                ...
# 69283  55004125                               New York Condominium
# 69287  55351522  Queens, NYC Centralized: 3 min-JFK; Secs. to LIRR
# 69288  55352074  New MidCentury Modern Apt In The Heart Of Broo...
# 69289  55352627                        Big and bright private room
# 69304  57363551        Sunny Brownstone Studio in BedStuy Brooklyn
#
#            host_id host_identity_verified     host_name neighbourhood_group  \
# 2      78829239556            unconfirmed         Elise           Manhattan
# ...

# %%
df.loc[df['review_rate_number']>4.5].loc[100:200]       #this way we can get check for multiple conditions at once
# Out:
#           id                                               name      host_id  \
# 113  1063746                   Beautiful Apartment East Village  95420528585
# 115  1064851  2 BR / 2 Bath Duplex Apt with patio! East Village  63842204720
# 128  1072030      Secluded Master Bedroom in Beautiful Huge Apt  44493053522
# 134  1075344               Unique & Charming small 1br Apt. LES  77518406270
# 136  1076449                                              blank  80835835733
# 139  1078106                                    FLAT MACDONOUGH  12359551036
# 142  1079763        Sun-drenched, artsy modernist 1 BDRM duplex  83716006050
# 148  1083076                                            NYC Zen  83696952551
# 149  1083629                   Cozy BR in Wiliamsburg 3 Bedroom  26995415534
# 155  1086943                Private Bdrm/Bathrm. New! Elevator!  80380133240
# 160  1089704                      CENTRAL PARK LOFT all for YOU  82585795978
# ...

# %% [markdown]
# iloc() -> can access a particular in df

# %%
df.iloc[0:4]    #upper_limit is excluded
# Out:
#         id                                 name      host_id  \
# 0  1001254   Clean & quiet apt home by the park  80014485718
# 1  1002102                Skylit Midtown Castle  52335172823
# 2  1002403  THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                blank  85098326012
#
#   host_identity_verified host_name neighbourhood_group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2            unconfirmed     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
#
#         lat      long  instant_bookable  ...  price service_fee  \
# 0  40.64749 -73.97237             False  ...  966.0       193.0
# 1  40.75362 -73.98377             False  ...  142.0        28.0
# 2  40.80902 -73.94190              True  ...  620.0       124.0
# ...

# %%
df.iloc[200:204]  #using iloc we can't access values of a particular column
# Out:
#           id                                name      host_id  \
# 200  1111796       cozy studio with parking spot  16211727428
# 201  1112348  Clean and convenient 2BR apartment  51018805199
# 202  1112901                               blank  21389589535
# 203  1113453                               blank  80926683538
#
#     host_identity_verified  host_name neighbourhood_group   neighbourhood  \
# 200            unconfirmed       Dale              Queens  Middle Village
# 201            unconfirmed      Lydia              Queens       Ridgewood
# 202            unconfirmed  Annabella              Queens  Middle Village
# 203            unconfirmed     Cherry            Brooklyn    Williamsburg
#
#           lat      long  instant_bookable  ...  price service_fee  \
# 200  40.71722 -73.87856              True  ...  938.0       188.0
# 201  40.70234 -73.89816              True  ...  405.0        81.0
# 202  40.71546 -73.87854              True  ...  907.0       181.0
# ...

# %% [markdown]
# rename-> renames the index ,column or row

# %%
vg_df=pd.read_csv(r"C:\Users\BAPS\Desktop\Python\Datasets\vgsales.csv",index_col='Name')
vg_df.head()
# Out:
#                           Rank Platform    Year         Genre Publisher  \
# Name
# Wii Sports                   1      Wii  2006.0        Sports  Nintendo
# Super Mario Bros.            2      NES  1985.0      Platform  Nintendo
# Mario Kart Wii               3      Wii  2008.0        Racing  Nintendo
# Wii Sports Resort            4      Wii  2009.0        Sports  Nintendo
# Pokemon Red/Pokemon Blue     5       GB  1996.0  Role-Playing  Nintendo
#
#                           NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Name
# Wii Sports                   41.49     29.02      3.77         8.46
# Super Mario Bros.            29.08      3.58      6.81         0.77
# Mario Kart Wii               15.85     12.88      3.79         3.31
# Wii Sports Resort            15.75     11.01      3.28         2.96
# Pokemon Red/Pokemon Blue     11.27      8.89     10.22         1.00
#
#                           Global_Sales
# Name
# Wii Sports                       82.74
# ...

# %%
vg_df.rename(index ={ "Wii Sports": "Wii sports "},inplace=True)        #renaming the index of a row

# %%
vg_df.head()
# Out:
#                           Rank Platform    Year         Genre Publisher  \
# Name
# Wii sports                   1      Wii  2006.0        Sports  Nintendo
# Super Mario Bros.            2      NES  1985.0      Platform  Nintendo
# Mario Kart Wii               3      Wii  2008.0        Racing  Nintendo
# Wii Sports Resort            4      Wii  2009.0        Sports  Nintendo
# Pokemon Red/Pokemon Blue     5       GB  1996.0  Role-Playing  Nintendo
#
#                           NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Name
# Wii sports                   41.49     29.02      3.77         8.46
# Super Mario Bros.            29.08      3.58      6.81         0.77
# Mario Kart Wii               15.85     12.88      3.79         3.31
# Wii Sports Resort            15.75     11.01      3.28         2.96
# Pokemon Red/Pokemon Blue     11.27      8.89     10.22         1.00
#
#                           Global_Sales
# Name
# Wii sports                       82.74
# ...

# %%
vg_df.rename(columns={'Rank': "Ranking"},inplace=True)  #renaming the name od column
vg_df.head(2)
# Out:
#                    Ranking Platform    Year     Genre Publisher  NA_Sales  \
# Name
# Wii sports               1      Wii  2006.0    Sports  Nintendo     41.49
# Super Mario Bros.        2      NES  1985.0  Platform  Nintendo     29.08
#
#                    EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Name
# Wii sports            29.02      3.77         8.46         82.74
# Super Mario Bros.      3.58      6.81         0.77         40.24

# %% [markdown]
# where() -> checks for condition ,same as used in SQL

# %%
check1 = df['review_rate_number']>4
check2 = df['neighbourhood_group']=="Queens"

cd1=df.where(check1,inplace=False)
cd2=cd1.where(check2,inplace=False)

cd2.dropna()
# Out:
#                id                                               name  \
# 230     1128365.0                  Nice, clean, safe, convenient 3BR
# 258     1143829.0  Safe cute near subway& Manhattan NY NY retro s...
# 349     1194089.0  Modern, Safe, Clean, Bright Room in Astoria for 2
# 361     1200716.0                                          Bienvenue
# 404     1224465.0      Forest Hills Apt minutes to midtown Manhattan
# ...           ...                                                ...
# 69132  39184597.0  Lovely open concept loft near subway, restaura...
# 69183  39212764.0                  Pat's Paradise  at Rockaway Beach
# 69203  45066592.0       New tidy  room attached by PRIVATE FULL BATH
# 69240  46500915.0       Private Room in Spacious Sunnyside Apartment
# 69287  55351522.0  Queens, NYC Centralized: 3 min-JFK; Secs. to LIRR
#
#             host_id host_identity_verified     host_name neighbourhood_group  \
# ...

# %% [markdown]
# drop() -> delete a column/row from dataset by column name/row index

# %%
myvar1
# Out:
#        cars  passings
# 0       BMW       3.0
# 1     Volvo       7.0
# 2      Ford       2.0
# 3      Audi       4.0
# 4  Mercedes       4.0

# %%
myvar1.drop('passings',axis=1)  #when deleting a column axis=1 for column
# Out:
#        cars
# 0       BMW
# 1     Volvo
# 2      Ford
# 3      Audi
# 4  Mercedes

# %%
myvar1.drop(4,inplace=True,errors='ignore')     #errors=ignore will not raise error if row/column to be droped is not present in the df already
myvar1
# Out:
#     cars  passings
# 0    BMW       3.0
# 1  Volvo       7.0
# 2   Ford       2.0
# 3   Audi       4.0

# %%
myvar1.drop(index=range(len('cars')))  #this truncates the df
# Out:
# Empty DataFrame
# Columns: [cars, passings]
# Index: []

# %%
# del myvar1  #this deletes the df now accessing this df will raise an error

# %% [markdown]
# groupby() -> groups the data

# %%
vg_df.shape
# Out:
# (16598, 10)

# %%
group_year=vg_df.groupby("Year")    #this is grouping the data on the basis of year
# group_year.last()   #this will print the last value of the group
group_year.first()  # this will print the first value of the group
# Out:
#         Ranking Platform         Genre                    Publisher  NA_Sales  \
# Year
# 1980.0      259     2600       Shooter                        Atari      4.00
# 1981.0      240     2600      Platform                   Activision      4.21
# 1982.0       90     2600        Puzzle                        Atari      7.28
# 1983.0      422      NES        Sports                     Nintendo      0.73
# 1984.0       10      NES       Shooter                     Nintendo     26.93
# 1985.0        2      NES      Platform                     Nintendo     29.08
# 1986.0      128      NES        Action                     Nintendo      3.74
# 1987.0      252      NES     Adventure                     Nintendo      2.19
# 1988.0       23      NES      Platform                     Nintendo      9.54
# 1989.0        6       GB        Puzzle                     Nintendo     23.20
# 1990.0       19     SNES      Platform                     Nintendo     12.78
# ...

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_identity_verified', 'host_name',
#        'neighbourhood_group', 'neighbourhood', 'lat', 'long',
#        'instant_bookable', 'cancellation_policy', 'room_type',
#        'construction_year', 'price', 'service_fee', 'minimum_nights',
#        'number_of_reviews', 'last_review', 'reviews_per_month',
#        'review_rate_number', 'calculated_host_listings_count',
#        'availability_365', 'house_rules'],
#       dtype='object')

# %%
group_1vg_df=vg_df.groupby(["Year","Genre"])
group_1vg_df.first()
# Out:
#                      Ranking Platform             Publisher  NA_Sales  \
# Year   Genre
# 1980.0 Action           5368     2600            Activision      0.32
#        Fighting         2671     2600            Activision      0.72
#        Misc             1768     2600            Activision      1.07
#        Shooter           259     2600                 Atari      4.00
#        Sports           4027     2600            Activision      0.46
# ...                      ...      ...                   ...       ...
# 2016.0 Sports            222      PS4       Electronic Arts      0.28
#        Strategy         7566       PC  Take-Two Interactive      0.09
# 2017.0 Action          16441      PSV          Idea Factory      0.00
#        Role-Playing    14393      PS4                  Sega      0.00
# 2020.0 Simulation       5959       DS               Ubisoft      0.27
#
#                      EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Year   Genre
# ...

# %%
vg_df=pd.read_csv(r"C:\Users\BAPS\Desktop\Python\Datasets\vgsales.csv")
vg_df.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %%
agg_data=vg_df.groupby("Year").agg(
    total_sale=('Global_Sales','sum'),
    mean_sale=("Global_Sales","mean"),
    Total_games=("Name","count"),
    Max_sales=("Global_Sales","max"),
    Min_sales=("Global_Sales","min")
    )
agg_data.T      #this way we can perform few aggregation operations on the grouped data
# Out:
# Year            1980.0     1981.0     1982.0     1983.0     1984.0     1985.0  \
# total_sale   11.380000  35.770000  28.860000  16.790000  50.360000  53.940000
# mean_sale     1.264444   0.777609   0.801667   0.987647   3.597143   3.852857
# Total_games   9.000000  46.000000  36.000000  17.000000  14.000000  14.000000
# Max_sales     4.310000   4.500000   7.810000   3.200000  28.310000  40.240000
# Min_sales     0.240000   0.130000   0.140000   0.170000   0.270000   0.020000
#
# Year            1986.0    1987.0  1988.0     1989.0  ...       2009.0  \
# total_sale   37.070000  21.74000  47.220  73.450000  ...   667.300000
# mean_sale     1.765238   1.35875   3.148   4.320588  ...     0.466317
# Total_games  21.000000  16.00000  15.000  17.000000  ...  1431.000000
# Max_sales     6.510000   4.38000  17.280  30.260000  ...    33.000000
# Min_sales     0.290000   0.07000   0.030   0.060000  ...     0.010000
#
# Year              2010.0      2011.0      2012.0      2013.0      2014.0  \
# ...

# %% [markdown]
# corr()-> finds co relation between all columns

# %%
df1=df[:5]
df1
df1.corr(method='pearson',min_periods=4,numeric_only=True)
# methods ->
# pearson: standard correlation coefficient 
# kendall: Kendall Tau correlation coefficient 
# spearman: Spearman rank correlation
# min_periods -> number of observation per column
# numeric only -> flag when true it only operates on numeric values
# Out:
#                                       id   host_id       lat      long  \
# id                              1.000000  0.483597  0.628862  0.654421
# host_id                         0.483597  1.000000 -0.011468  0.758889
# lat                             0.628862 -0.011468  1.000000  0.587305
# long                            0.654421  0.758889  0.587305  1.000000
# instant_bookable                0.141665  0.260254  0.107644  0.482214
# construction_year              -0.603656  0.111475 -0.622349 -0.357589
# price                          -0.702861  0.248481 -0.524323  0.003076
# service_fee                    -0.700225  0.252453 -0.524526  0.006214
# minimum_nights                  0.013074 -0.250782 -0.526996 -0.670352
# number_of_reviews               0.171122  0.146734 -0.433905 -0.102782
# reviews_per_month               0.171042  0.238396 -0.368959  0.054464
# review_rate_number             -0.509817 -0.309557  0.052639  0.040967
# ...

# %%
# df1.corr(method='kendall')

# %%
import pandas as pd

# %%
col=["Player","Role"]
player_data=[("Virat Kohli","Batter"),("Jasprit Bumrah","Bowler")]

pdf=pd.DataFrame(player_data,index=range(len(player_data)),columns=col)
player_data.extend([("Smriti Mandhana","Batter"),("Rohit Sharma","Batter"),("Joe Root","Batter"),("Steve Smith","Batter"),("Adam Gilchrist","Wicket Keeper"),("Shane Warne","Bowler"),("Brett Lee","Bowler"),("Micheal Holding","Bowler"),("Malcom Marshell","Bowler")])

pdf=pd.DataFrame(player_data,index=range(len(player_data)),columns=col)
print(pdf)
# Out:
#              Player           Role
# 0       Virat Kohli         Batter
# 1    Jasprit Bumrah         Bowler
# 2   Smriti Mandhana         Batter
# 3      Rohit Sharma         Batter
# 4          Joe Root         Batter
# 5       Steve Smith         Batter
# 6    Adam Gilchrist  Wicket Keeper
# 7       Shane Warne         Bowler
# 8         Brett Lee         Bowler
# 9   Micheal Holding         Bowler
# 10  Malcom Marshell         Bowler

# %%
pdf
# Out:
#              Player           Role
# 0       Virat Kohli         Batter
# 1    Jasprit Bumrah         Bowler
# 2   Smriti Mandhana         Batter
# 3      Rohit Sharma         Batter
# 4          Joe Root         Batter
# 5       Steve Smith         Batter
# 6    Adam Gilchrist  Wicket Keeper
# 7       Shane Warne         Bowler
# 8         Brett Lee         Bowler
# 9   Micheal Holding         Bowler
# 10  Malcom Marshell         Bowler

# %% [markdown]
# Merging two df

# %%
col1=["Player","Strike_Rate","Economy"]
player_data1=[("Rohit Sharma",96.91,6.90),("Smriti Mandhana",91.54,6.38),("Virat Kohli",95.32,5.70),("Joe Root",90.85,6.37),("Steve Smith",88.66,5.76),("Adam Gilchrist",106.86,None),("Shane Warne",74,4.72),("Brett Lee",92.94,5.36),("Jason Gillespie",82.273,6.436)]
pdf1=pd.DataFrame(player_data1,index=range(len(player_data1)),columns=col1)

pdf1
# Out:
#             Player  Strike_Rate  Economy
# 0     Rohit Sharma       96.910    6.900
# 1  Smriti Mandhana       91.540    6.380
# 2      Virat Kohli       95.320    5.700
# 3         Joe Root       90.850    6.370
# 4      Steve Smith       88.660    5.760
# 5   Adam Gilchrist      106.860      NaN
# 6      Shane Warne       74.000    4.720
# 7        Brett Lee       92.940    5.360
# 8  Jason Gillespie       82.273    6.436

# %%
m_df=pd.merge(pdf,pdf1,on='Player',how='inner')

m_df
# Out:
#             Player           Role  Strike_Rate  Economy
# 0      Virat Kohli         Batter        95.32     5.70
# 1  Smriti Mandhana         Batter        91.54     6.38
# 2     Rohit Sharma         Batter        96.91     6.90
# 3         Joe Root         Batter        90.85     6.37
# 4      Steve Smith         Batter        88.66     5.76
# 5   Adam Gilchrist  Wicket Keeper       106.86      NaN
# 6      Shane Warne         Bowler        74.00     4.72
# 7        Brett Lee         Bowler        92.94     5.36

# %%
m=pdf1[["Player","Strike_Rate"]]
m
# Out:
#             Player  Strike_Rate
# 0     Rohit Sharma       96.910
# 1  Smriti Mandhana       91.540
# 2      Virat Kohli       95.320
# 3         Joe Root       90.850
# 4      Steve Smith       88.660
# 5   Adam Gilchrist      106.860
# 6      Shane Warne       74.000
# 7        Brett Lee       92.940
# 8  Jason Gillespie       82.273

# %%
m_df1=pd.merge(pdf,m)

m_df1
# Out:
#             Player           Role  Strike_Rate
# 0      Virat Kohli         Batter        95.32
# 1  Smriti Mandhana         Batter        91.54
# 2     Rohit Sharma         Batter        96.91
# 3         Joe Root         Batter        90.85
# 4      Steve Smith         Batter        88.66
# 5   Adam Gilchrist  Wicket Keeper       106.86
# 6      Shane Warne         Bowler        74.00
# 7        Brett Lee         Bowler        92.94
